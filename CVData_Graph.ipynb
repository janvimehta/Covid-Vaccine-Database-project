# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\JANVI\Desktop\Dmdd_Assignment 3\cvdata.csv")
df.head()
# Out:
#    Unnamed: 0  Updated On    State  Total_Doses_Administered  Sessions  \
# 0           0  16/01/2021  Gujarat                      1146       107
# 1           1  17/01/2021  Gujarat                      2313       351
# 2           2  18/01/2021  Gujarat                      2182       598
# 3           3  19/01/2021  Gujarat                      4842       700
# 4           4  20/01/2021  Gujarat                      4877       932
#
#     Sites   First_Dose_Administered  Second_Dose_Administered  \
# 0       95                     1146                         0
# 1      189                     2313                         0
# 2      287                     2182                         0
# 3      313                     4842                         0
# 4      409                     4877                         0
#
#    Male_Doses_Administered  Female_Doses_Administered  ...  \
# 0                      592                        554  ...
# ...

# %%
df=pd.read_csv("C:\\Users\JANVI\Desktop\Dmdd_Assignment 3\cvdata.csv")
df.corr()
# Out:
#                                     Unnamed: 0  Total_Doses_Administered  \
# Unnamed: 0                            1.000000                  0.542677
# Total_Doses_Administered              0.542677                  1.000000
# Sessions                              0.366124                  0.801814
#  Sites                                0.035172                  0.497879
# First_Dose_Administered               0.536997                  0.999086
# Second_Dose_Administered              0.554497                  0.989534
# Male_Doses_Administered               0.545421                  0.992712
# Female_Doses_Administered             0.544298                  0.993684
# Transgender_Doses_Administered        0.543168                  0.984912
#  Covaxin_Doses_Administered           0.529588                  0.997473
# CoviShield_Doses_Administered         0.544695                  0.999946
# Sputnik_V_Doses_Administered          0.334167                  0.626405
# ...

# %%
from scipy import stats
r,p =stats.pearsonr(df.Total_Individuals_Vaccinated, df.Male_Doses_Administered)
print(round(r,3))
print(round(p,20))
# Out:
# 0.306
# 2.2e-19

# %%
corr_df = pd.DataFrame(columns=['r','p'])

for col in df:
    if pd.api.types.is_numeric_dtype(df[col]) and col != 'Total_Individuals_Vaccinated':
        r, p = stats.pearsonr(df.Total_Individuals_Vaccinated, df[col])
        corr_df.loc[col] = [round(r, 3), round(p, 20)]
        
corr_df
# Out:
# C:\Users\JANVI\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\JANVI\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\JANVI\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
#                                         r             p
# Unnamed: 0                          0.144  3.340843e-05
# Total_Doses_Administered            0.416  0.000000e+00
# Sessions                            0.586  0.000000e+00
#  Sites                              0.611  0.000000e+00
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df.Female_Doses_Administered, df.Total_Doses_Administered)
plt.title('Vaccination Graph')
plt.xlabel('Female_Doses_Administered')
plt.ylabel('Total_Doses_Administered')
plt.show()

# %%
df_State = df[df['State'] == 'Gujarat']
df_DiffState = df[df['State'] == 'Maharashtra']

plt.scatter(df_State.Female_Doses_Administered, df_State.Total_Doses_Administered, label='Gujarat')
plt.scatter(df_DiffState.Female_Doses_Administered, df_DiffState.Total_Doses_Administered, label='Maharashtra')
plt.title('Vaccination Graph')
plt.xlabel('Female_Doses_Administered')
plt.ylabel('Total_Doses_Administered')
plt.legend()
plt.show()

# %%
df_State_reduced = df_State.sample(50)
df_DiffState_reduced = df_DiffState.sample(50)

plt.scatter(df_State_reduced.Female_Doses_Administered, df_State_reduced.Total_Doses_Administered, label='Gujarat')
plt.scatter(df_DiffState_reduced.Female_Doses_Administered, df_DiffState_reduced.Total_Doses_Administered, label='Maharashtra')
plt.title('Vaccination Graph')
plt.xlabel('Female_Doses_Administered')
plt.ylabel('Total_Doses_Administered')
plt.legend()
plt.show()

# %%
corelation=df.corr()
print(corelation.columns)
# Out:
# Index(['Unnamed: 0', 'Total_Doses_Administered', 'Sessions', ' Sites ',
#        'First_Dose_Administered', 'Second_Dose_Administered',
#        'Male_Doses_Administered', 'Female_Doses_Administered',
#        'Transgender_Doses_Administered', ' Covaxin_Doses_Administered',
#        'CoviShield_Doses_Administered', 'Sputnik_V_Doses_Administered', 'AEFI',
#        '60_Years_Doses Administered', '18_44_Years_Individuals_Vaccinated',
#        '45_60_Years_Individuals_Vaccinated',
#        '60_Years_Individuals_Vaccinated_', 'Male_Individuals_Vaccinated',
#        'Female_Individuals_Vaccinated', 'Transgender_Individuals_Vaccinated',
#        'Total_Individuals_Vaccinated'],
#       dtype='object')

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
#Scatter Plot
sns.relplot(x= 'State', y='Total_Doses_Administered', hue='State', data=df)

# %%
df.corr()
# Out:
#                                     Unnamed: 0  Total_Doses_Administered  \
# Unnamed: 0                            1.000000                  0.542677
# Total_Doses_Administered              0.542677                  1.000000
# Sessions                              0.366124                  0.801814
#  Sites                                0.035172                  0.497879
# First_Dose_Administered               0.536997                  0.999086
# Second_Dose_Administered              0.554497                  0.989534
# Male_Doses_Administered               0.545421                  0.992712
# Female_Doses_Administered             0.544298                  0.993684
# Transgender_Doses_Administered        0.543168                  0.984912
#  Covaxin_Doses_Administered           0.529588                  0.997473
# CoviShield_Doses_Administered         0.544695                  0.999946
# Sputnik_V_Doses_Administered          0.334167                  0.626405
# ...
